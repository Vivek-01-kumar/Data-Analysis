# %% [markdown]
# # PYTHON ASSIGNMENT
# ## The company wants to analyze data on previous movies from IMDb source for movie ratings

# %% [markdown]
# ### 1. Import the data set into a Pandas DataFrame.

# %%
import pandas as pd 
df = pd.read_csv(r'D:\python assignment\Movie Assignment Data.csv')
df
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ### 2.Generate descriptive statistics for the budget of all the movies.

# %%
df['budget'].describe()
# Out:
# count    1.000000e+02
# mean     7.838400e+07
# std      7.445295e+07
# min      3.000000e+06
# 25%      1.575000e+07
# 50%      4.225000e+07
# 75%      1.500000e+08
# max      2.600000e+08
# Name: budget, dtype: float64

# %% [markdown]
# ### 3.Find out how many of the top-rated movies produced in the United States have a PG-13 rating.

# %%
# We want top-rated movies with content rating  PG-13 only 

movie_content_rating = df.content_rating == 'PG-13'

# and country USA only 

movie_country = df.Country == 'USA'


df[ movie_content_rating   &  movie_country  ].Title.value_counts()
# Out:
# La La Land                                    1
# True Grit                                     1
# Les MisÃ©rables                               1
# Scott Pilgrim vs. the World                   1
# Captain Phillips                              1
# Moneyball                                     1
# The Social Network                            1
# Bridge of Spies                               1
# Creed                                         1
# The Martian                                   1
# The Help                                      1
# Warrior                                       1
# The Book Thief                                1
# Moonrise Kingdom                              1
# The Perks of Being a Wallflower               1
# The Fault in Our Stars                        1
# Rise of the Planet of the Apes                1
# The Hunger Games: Catching Fire               1
# Arrival                                       1
# Star Trek Into Darkness                       1
# ...

# %% [markdown]
# ### 4.Find out whether any of the top-rated movies produced in 2014 were not produced in the United States.

# %%
# Did not want USA as a country in top-rated movies 

movie_country = df.Country != 'USA'

# But we want movies from year 2014

movie_title_year = df.title_year == 2014

df[ movie_country   &  movie_title_year  ]
# Out:
#                        Title  title_year    budget      Gross  \
# 45            The Lego Movie        2014  60000000  257756197
# 78  The Theory of Everything        2014  15000000   35887263
# 80                Ex Machina        2014  15000000   25440971
# 81        The Imitation Game        2014  14000000   91121452
#
#             actor_1_name   actor_2_name    actor_3_name  \
# 45        Morgan Freeman   Will Ferrell     Alison Brie
# 78        Eddie Redmayne   Emily Watson  Simon McBurney
# 80         Elina Alminas  Sonoya Mizuno   Corey Johnson
# 81  Benedict Cumberbatch   Rory Kinnear     Allen Leech
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 45                   11000                  8000.0                  2000.0
# 78                   13000                   876.0                   149.0
# 80                     149                   145.0                   123.0
# ...

# %% [markdown]
# ### 5.Find the percentage of the top-rated movies that are in: 1 genre only, 2 genres only and 3 genres only

# %%
spaces_in_genre1 = df['genre_1'].isna().sum()
spaces_in_genre2 = df['genre_2'].isna().sum()
spaces_in_genre3 = df['genre_3'].isna().sum() 

print(f'total no. of movies with space in genre 1 only : {spaces_in_genre1}')
print(f'total no. of movies with space in genre 1 only : {spaces_in_genre2}')
print(f'total no. of movies with space in genre 1 only : {spaces_in_genre3}')
print('*************************************************************************************')
# If genre 2 has spaces that means it belongs to 1 genre only 
total_in_genre1_only = spaces_in_genre2
print(f" percentage of movies in 1 genre only is : {total_in_genre1_only}")

# If genre 3 with spaces is 26, hten 100 - 26 = 74 records in total have values in genre 3
total_in_genre3_only = 100 - spaces_in_genre3      
print(f" percentage of movies in 3 genre only is : {total_in_genre3_only}")    

# We get genre 2 only percentage finding the remaning percentage after adding genre 1 only and genre 3 only 
total_in_genre2_only = 100 - (total_in_genre1_only + total_in_genre3_only)     
print(f" percentage of movies in 2 genre only is : {total_in_genre2_only}")
# Out:
# total no. of movies with space in genre 1 only : 0
# total no. of movies with space in genre 1 only : 3
# total no. of movies with space in genre 1 only : 26
# *************************************************************************************
#  percentage of movies in 1 genre only is : 3
#  percentage of movies in 3 genre only is : 74
#  percentage of movies in 2 genre only is : 23

# %% [markdown]
# ### 6.Convert the budget and gross values from “dollars” to “dollars in millions” for all top-rated movies. Round the converted values down to 3 decimal places.

# %%
def converter(budget):
    
    return str(round(budget/1000000,3))+'million'

df['budget'] = df.budget.apply(converter)
df['Gross'] = df.Gross.apply(converter) 
df
# Out:
#                                            Title  title_year        budget  \
# 0                                     La La Land        2016   30.0million
# 1                                       Zootopia        2016  150.0million
# 2                                           Lion        2016   12.0million
# 3                                        Arrival        2016   47.0million
# 4                          Manchester by the Sea        2016    9.0million
# ..                                           ...         ...           ...
# 95                                      Whiplash        2014    3.3million
# 96                               Before Midnight        2013    3.0million
# 97    Star Wars: Episode VII - The Force Awakens        2015  245.0million
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150.0million
# 99                       Tucker and Dale vs Evil        2010    5.0million
#
#              Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# ### 7.List all details for the top 10 movies with the highest profit, sorted from highest to lowest.

# %%
import pandas as pd 
df = pd.read_csv(r'D:\python assignment\Movie Assignment Data.csv')
# for profit we want to subtract gross from budget 

df['profit'] = df['Gross'] - df['budget']

# we want top ten movies, so we have to sort values in descending order i.e higest to lowest

df.sort_values(by='profit', ascending=False).Title.value_counts().head(10)
# Out:
# Star Wars: Episode VII - The Force Awakens    1
# Spotlight                                     1
# Fury                                          1
# Kick-Ass                                      1
# Drive                                         1
# The Theory of Everything                      1
# Boyhood                                       1
# Dallas Buyers Club                            1
# Interstellar                                  1
# Nightcrawler                                  1
# Name: Title, dtype: int64

# %% [markdown]
# ### 8.Generate a list of all the actors, in alphabetical order by the first name, that have starred in a top-rated movie. If an actor has starred in multiple movies, their name should appear only once on the list.

# %%
actor_name1 = df['actor_1_name']
actor_name2 = df['actor_2_name']
actor_name3 = df['actor_3_name']

# merge all the columns of the lead actor,second lead actor and third lead actor in the movie

all_actors_names = pd.concat([actor_name1,actor_name2,actor_name3])

# sort all the actors in alphabetical order, remove duplicates and display their names 

print(f'list of actors that have starred in top-rated movies (in alphabetical order) are:\n{all_actors_names.drop_duplicates().sort_values()}')
# Out:
# list of actors that have starred in top-rated movies (in alphabetical order) are:
# 97                  0
# 23    Abraham Benrubi
# 10         Adam Brown
# 82        Aidan Quinn
# 10       Aidan Turner
#            ...
# 99       Tyler Labine
# 19         Vin Diesel
# 45       Will Ferrell
# 87         Will Forte
# 29       ZoÃ« Kravitz
# Length: 235, dtype: object

# %% [markdown]
# ### 9.The movie studio wants to determine who it should approach to act in its next movie production. Find the top 3 actors who appeared in the most top-rated movies.

# %%
actor_1 = df['actor_1_name']
actor_2 = df['actor_2_name']
actor_3 = df['actor_3_name']

# merge all the columns of the lead actor,second lead actor and third lead actor in the movie

movies_actor = pd.concat([actor_1, actor_2, actor_3])

# Top three actors who appeared in the most top-rated movies.

movies_actor.value_counts().head(3)
# Out:
# Tom Hardy            5
# Leonardo DiCaprio    5
# Jennifer Lawrence    4
# dtype: int64

# %% [markdown]
# ### 10.Create a data visualization that shows each country and the number of top-rated movies produced in it. Find the country that produced the most top-rated movies.

# %%
import matplotlib.pyplot as plt
movie_data_visual = df['Country'].value_counts()
movie_data_visual.to_frame()
movie_data_visual.plot(kind='bar' ,y='country', figsize=(20,12))
plt.xlabel('countries')
plt.ylabel('no. of movies')
plt.show()
print(f'country that has produced the most top rated movies is {df["Country"].value_counts().head(1)}')
# Out:
# country that has produced the most top rated movies is USA    81
# Name: Country, dtype: int64
